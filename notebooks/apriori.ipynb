# %%
import pandas as pd  
import os

store_data = pd.read_csv(os.getcwd() + '/data/store_data.csv', header=None)  

display(store_data.head())
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
import numpy as np  
import matplotlib.pyplot as plt  
from apyori import apriori  

records = []  
for i in range(0, 7501):  
    records.append([str(store_data.values[i,j]) for j in range(0, 20)])

association_rules = apriori(records, min_support=0.0093, min_confidence=0.3, min_lift=1.5, min_length=2)  
association_results = list(association_rules)  

print(association_results[0])
# Out:
# RelationRecord(items=frozenset(['burgers', 'eggs']), support=0.02879616051193174, ordered_statistics=[OrderedStatistic(items_base=frozenset(['burgers']), items_add=frozenset(['eggs']), confidence=0.33027522935779813, lift=1.8378297443715457)])

# %%
for item in association_results:

    pair = item[0] 
    items = [x for x in pair]
    
    print("Rule: " + items[0] + " -> " + items[1])
    print("Support: " + str(item[1]))
    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("\n")
# Out:
# Rule: burgers -> eggs
# Support: 0.0287961605119
# Confidence: 0.330275229358
# Lift: 1.83782974437
#
#
# Rule: mineral water -> cereals
# Support: 0.0102652979603
# Confidence: 0.39896373057
# Lift: 1.67372871533
#
#
# Rule: chicken -> mineral water
# Support: 0.0227969604053
# Confidence: 0.38
# Lift: 1.59417225951
#
#
# Rule: mineral water -> cooking oil
# Support: 0.0201306492468
# Confidence: 0.394255874674
# Lift: 1.65397836461
#
#
# Rule: spaghetti -> cooking oil
# Support: 0.0158645513931
# Confidence: 0.310704960836
# Lift: 1.7845313256
#
#
# Rule: turkey -> eggs
# Support: 0.0194640714571
# Confidence: 0.311300639659
# Lift: 1.73224487988
#
#
# Rule: mineral water -> frozen vegetables
# Support: 0.0357285695241
# Confidence: 0.374825174825
# Lift: 1.57246288387
#
#
# Rule: spaghetti -> grated cheese
# Support: 0.0165311291828
# Confidence: 0.315521628499
# Lift: 1.81219581575
#
#
# Rule: herb & pepper -> ground beef
# Support: 0.0159978669511
# Confidence: 0.323450134771
# Lift: 3.29199384113
#
#
# Rule: mineral water -> ground beef
# Support: 0.0409278762832
# Confidence: 0.416553595658
# Lift: 1.7475215442
#
#
# Rule: spaghetti -> ground beef
# Support: 0.0391947740301
# Confidence: 0.398914518318
# Lift: 2.29116217603
#
#
# Rule: spaghetti -> herb & pepper
# Support: 0.0162644980669
# Confidence: 0.32884097035
# Lift: 1.88869534349
#
#
# Rule: mineral water -> milk
# Support: 0.0479936008532
# Confidence: 0.37037037037
# Lift: 1.55377413207
#
#
# Rule: soup -> milk
# Support: 0.0151979736035
# Confidence: 0.300791556728
# Lift: 2.32123196195
#
#
# Rule: whole wheat pasta -> milk
# Support: 0.0098653512865
# Confidence: 0.334841628959
# Lift: 2.58399903171
#
#
# Rule: olive oil -> mineral water
# Support: 0.0275963204906
# Confidence: 0.419028340081
# Lift: 1.75790356764
#
#
# Rule: mineral water -> red wine
# Support: 0.0109318757499
# Confidence: 0.388625592417
# Lift: 1.63035825991
#
#
# Rule: mineral water -> salmon
# Support: 0.0170643914145
# Confidence: 0.401253918495
# Lift: 1.68333648917
#
#
# Rule: soup -> mineral water
# Support: 0.0230635915211
# Confidence: 0.456464379947
# Lift: 1.91495487359
#
#
# Rule: olive oil -> spaghetti
# Support: 0.0229302759632
# Confidence: 0.348178137652
# Lift: 1.99975820102
#
#
# Rule: pepper -> spaghetti
# Support: 0.0098653512865
# Confidence: 0.371859296482
# Lift: 2.1357707373
#
#
# Rule: spaghetti -> red wine
# Support: 0.0102652979603
# Confidence: 0.364928909953
# Lift: 2.09596612064
#
#
# Rule: spaghetti -> salmon
# Support: 0.0134648713505
# Confidence: 0.316614420063
# Lift: 1.81847225489
#
#
# Rule: spaghetti -> tomatoes
# Support: 0.0209305425943
# Confidence: 0.30604288499
# Lift: 1.75775473224
#
#
# Rule: burgers -> eggs
# Support: 0.0287961605119
# Confidence: 0.330275229358
# Lift: 1.83782974437
#
#
# Rule: nan -> mineral water
# Support: 0.0102652979603
# Confidence: 0.39896373057
# Lift: 1.67372871533
#
#
# Rule: chicken -> nan
# Support: 0.0227969604053
# Confidence: 0.38
# Lift: 1.59417225951
#
#
# Rule: eggs -> mineral water
# Support: 0.0134648713505
# Confidence: 0.40562248996
# Lift: 1.70166347717
#
#
# Rule: eggs -> spaghetti
# Support: 0.0105319290761
# Confidence: 0.317269076305
# Lift: 1.82223226751
#
#
# Rule: mineral water -> frozen vegetables
# Support: 0.00973203572857
# Confidence: 0.424418604651
# Lift: 1.78051675251
#
#
# Rule: mineral water -> ground beef
# Support: 0.0109318757499
# Confidence: 0.473988439306
# Lift: 1.98847163492
#
#
# Rule: mineral water -> milk
# Support: 0.0139981335822
# Confidence: 0.435684647303
# Lift: 1.82777994375
#
#
# Rule: spaghetti -> milk
# Support: 0.0109318757499
# Confidence: 0.340248962656
# Lift: 1.95421705121
#
#
# Rule: pancakes -> mineral water
# Support: 0.00933208905479
# Confidence: 0.469798657718
# Lift: 1.97089470444
#
#
# Rule: mineral water -> spaghetti
# Support: 0.0158645513931
# Confidence: 0.301265822785
# Lift: 1.7303177157
#
#
# Rule: mineral water -> nan
# Support: 0.0201306492468
# Confidence: 0.394255874674
# Lift: 1.65397836461
#
#
# Rule: spaghetti -> nan
# Support: 0.0158645513931
# Confidence: 0.310704960836
# Lift: 1.7845313256
#
#
# Rule: eggs -> mineral water
# Support: 0.0101319824023
# Confidence: 0.506666666667
# Lift: 2.12556301268
#
#
# Rule: mineral water -> eggs
# Support: 0.0130649246767
# Confidence: 0.424242424242
# Lift: 1.77977764219
#
#
# Rule: eggs -> spaghetti
# Support: 0.014264764698
# Confidence: 0.390510948905
# Lift: 1.63826768889
#
#
# Rule: turkey -> eggs
# Support: 0.0194640714571
# Confidence: 0.311300639659
# Lift: 1.73224487988
#
#
# Rule: mineral water -> spaghetti
# Support: 0.0101319824023
# Confidence: 0.300395256917
# Lift: 1.72531762797
#
#
# Rule: mineral water -> frozen vegetables
# Support: 0.0110651913078
# Confidence: 0.468926553672
# Lift: 1.96723606213
#
#
# Rule: mineral water -> frozen vegetables
# Support: 0.0357285695241
# Confidence: 0.374825174825
# Lift: 1.57246288387
#
#
# Rule: mineral water -> frozen vegetables
# Support: 0.0119984002133
# Confidence: 0.335820895522
# Lift: 1.92878448493
#
#
# Rule: spaghetti -> nan
# Support: 0.0165311291828
# Confidence: 0.315521628499
# Lift: 1.81219581575
#
#
# Rule: nan -> herb & pepper
# Support: 0.0159978669511
# Confidence: 0.323450134771
# Lift: 3.29199384113
#
#
# Rule: mineral water -> milk
# Support: 0.0110651913078
# Confidence: 0.50303030303
# Lift: 2.11030777574
#
#
# Rule: spaghetti -> milk
# Support: 0.00973203572857
# Confidence: 0.442424242424
# Lift: 2.54105990997
#
#
# Rule: mineral water -> nan
# Support: 0.0409278762832
# Confidence: 0.416553595658
# Lift: 1.7475215442
#
#
# Rule: mineral water -> spaghetti
# Support: 0.0170643914145
# Confidence: 0.416938110749
# Lift: 2.39468052736
#
#
# Rule: spaghetti -> nan
# Support: 0.0391947740301
# Confidence: 0.398914518318
# Lift: 2.29116217603
#
#
# Rule: nan -> spaghetti
# Support: 0.0162644980669
# Confidence: 0.32884097035
# Lift: 1.88869534349
#
#
# Rule: mineral water -> nan
# Support: 0.0479936008532
# Confidence: 0.37037037037
# Lift: 1.55377413207
#
#
# Rule: mineral water -> spaghetti
# Support: 0.0157312358352
# Confidence: 0.327777777778
# Lift: 1.8825889059
#
#
# Rule: soup -> nan
# Support: 0.0151979736035
# Confidence: 0.300791556728
# Lift: 2.32123196195
#
#
# Rule: whole wheat pasta -> nan
# Support: 0.0098653512865
# Confidence: 0.334841628959
# Lift: 2.58399903171
#
#
# Rule: olive oil -> mineral water
# Support: 0.0274630049327
# Confidence: 0.41784989858
# Lift: 1.75295978146
#
#
# Rule: red wine -> mineral water
# Support: 0.0109318757499
# Confidence: 0.388625592417
# Lift: 1.63035825991
#
#
# Rule: salmon -> mineral water
# Support: 0.0169310758566
# Confidence: 0.399371069182
# Lift: 1.67543757826
#
#
# Rule: soup -> mineral water
# Support: 0.0230635915211
# Confidence: 0.456464379947
# Lift: 1.91495487359
#
#
# Rule: olive oil -> mineral water
# Support: 0.0102652979603
# Confidence: 0.371980676329
# Lift: 2.13646788142
#
#
# Rule: pancakes -> mineral water
# Support: 0.0114651379816
# Confidence: 0.339920948617
# Lift: 1.95233310534
#
#
# Rule: mineral water -> spaghetti
# Support: 0.00933208905479
# Confidence: 0.382513661202
# Lift: 2.19696399133
#
#
# Rule: olive oil -> spaghetti
# Support: 0.0229302759632
# Confidence: 0.348884381339
# Lift: 2.00381450568
#
#
# Rule: spaghetti -> pepper
# Support: 0.0098653512865
# Confidence: 0.371859296482
# Lift: 2.1357707373
#
#
# Rule: red wine -> spaghetti
# Support: 0.0102652979603
# Confidence: 0.364928909953
# Lift: 2.09596612064
#
#
# Rule: salmon -> spaghetti
# Support: 0.0134648713505
# Confidence: 0.317610062893
# Lift: 1.8241907211
#
#
# Rule: spaghetti -> nan
# Support: 0.0209305425943
# Confidence: 0.30604288499
# Lift: 1.75775473224
#
#
# Rule: eggs -> nan
# Support: 0.0134648713505
# Confidence: 0.40562248996
# Lift: 1.70166347717
#
#
# Rule: spaghetti -> eggs
# Support: 0.0105319290761
# Confidence: 0.317269076305
# Lift: 1.82223226751
#
#
# Rule: mineral water -> frozen vegetables
# Support: 0.00973203572857
# Confidence: 0.424418604651
# Lift: 1.78051675251
#
#
# Rule: mineral water -> nan
# Support: 0.0109318757499
# Confidence: 0.473988439306
# Lift: 1.98847163492
#
#
# Rule: mineral water -> nan
# Support: 0.0139981335822
# Confidence: 0.435684647303
# Lift: 1.82777994375
#
#
# Rule: spaghetti -> nan
# Support: 0.0109318757499
# Confidence: 0.340248962656
# Lift: 1.95421705121
#
#
# Rule: pancakes -> mineral water
# Support: 0.00933208905479
# Confidence: 0.469798657718
# Lift: 1.97089470444
#
#
# Rule: spaghetti -> mineral water
# Support: 0.0158645513931
# Confidence: 0.301265822785
# Lift: 1.7303177157
#
#
# Rule: eggs -> nan
# Support: 0.0101319824023
# Confidence: 0.506666666667
# Lift: 2.12556301268
#
#
# Rule: mineral water -> eggs
# Support: 0.0130649246767
# Confidence: 0.424242424242
# Lift: 1.77977764219
#
#
# Rule: spaghetti -> eggs
# Support: 0.014264764698
# Confidence: 0.390510948905
# Lift: 1.63826768889
#
#
# Rule: spaghetti -> mineral water
# Support: 0.0101319824023
# Confidence: 0.300395256917
# Lift: 1.72531762797
#
#
# Rule: mineral water -> frozen vegetables
# Support: 0.0110651913078
# Confidence: 0.468926553672
# Lift: 1.96723606213
#
#
# Rule: spaghetti -> mineral water
# Support: 0.0119984002133
# Confidence: 0.335820895522
# Lift: 1.92878448493
#
#
# Rule: mineral water -> nan
# Support: 0.0110651913078
# Confidence: 0.50303030303
# Lift: 2.11030777574
#
#
# Rule: spaghetti -> nan
# Support: 0.00973203572857
# Confidence: 0.442424242424
# Lift: 2.54105990997
#
#
# Rule: spaghetti -> mineral water
# Support: 0.0170643914145
# Confidence: 0.416938110749
# Lift: 2.39468052736
#
#
# Rule: spaghetti -> mineral water
# Support: 0.0157312358352
# Confidence: 0.327777777778
# Lift: 1.8825889059
#
#
# Rule: olive oil -> spaghetti
# Support: 0.0102652979603
# Confidence: 0.373786407767
# Lift: 2.14683908473
#
#
# Rule: pancakes -> spaghetti
# Support: 0.0114651379816
# Confidence: 0.339920948617
# Lift: 1.95233310534
#
#
# Rule: spaghetti -> mineral water
# Support: 0.00933208905479
# Confidence: 0.382513661202
# Lift: 2.19696399133
