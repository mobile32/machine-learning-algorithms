# %%
from pandas import DataFrame
import matplotlib.pyplot as plt


Data = {
    'x': [35, 35, 5, 18, 36, 22, 39, 3, 21, 46, 45, 9, 9, 39, 80, 22, 24, 44, 95, 44, 90, 5, 12, 41, 40, 53, 49, 62, 41,
          21, 8, 13, 35, 46, 39, 31, 41, 53, 32, 25, 88, 48, 72, 83, 95, 4, 37, 2, 62, 94, 35, 65, 58, 31, 7, 16, 29,
          93, 71, 41, 16, 70, 60, 87, 27, 47, 3, 36, 6, 63, 7, 39, 66, 21, 74, 33, 79, 54, 15, 17, 10, 14, 46, 86, 68,
          98, 26, 91, 79, 63, 20, 51, 15, 33, 61, 22, 55, 24, 73, 37, ],
    'y': [
        7, 21, 63, 52, 17, 22, 5, 56, 99, 8, 45, 68, 28, 80, 60, 70, 23, 32, 70, 51, 39, 89, 98, 95, 10, 76, 19, 67, 64,
        84, 23, 73, 32, 68, 28, 88, 25, 48, 29, 22, 85, 96, 94, 84, 1, 67, 54, 96, 72, 63, 64, 59, 9, 20, 52, 59, 92,
        62, 95, 88, 44, 86, 71, 21, 69, 36, 3, 54, 72, 20, 96, 83, 86, 23, 68, 48, 96, 52, 89, 40, 1, 14, 69, 9, 54, 47,
        18, 22, 93, 84, 68, 79, 8, 54, 76, 6, 20, 12, 56, 41, ]
}

df = DataFrame(Data, columns=['x', 'y'])
plt.scatter(df['x'], df['y'], s=50, alpha=0.5)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3).fit(df)
centroids = kmeans.cluster_centers_
print(centroids)

plt.scatter(df['x'], df['y'], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
# Out:
# [[73.62068966 67.75862069]
#  [35.08571429 19.34285714]
#  [24.11111111 72.55555556]]

# %%
kmeans = KMeans(n_clusters=6).fit(df)
centroids = kmeans.cluster_centers_
print(centroids)

plt.scatter(df['x'], df['y'], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
# Out:
# [[11.41176471 74.64705882]
#  [74.19047619 75.28571429]
#  [87.14285714 22.71428571]
#  [29.40740741 16.77777778]
#  [36.875      48.6875    ]
#  [40.41666667 84.41666667]]
